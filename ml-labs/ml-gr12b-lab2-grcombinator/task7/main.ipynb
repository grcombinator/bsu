# %%
from clases import RomanToInteger, Subsets, TwoSum, ReverseString

roman = RomanToInteger()
print(roman.solve("LVIII"))   
print(roman.solve("MCMXCIV"))
# Out:
# 58
# 1994

# %%
subsets = Subsets()
print(subsets.solve([1, 2, 3]))
# Out:
# [[], [1], [1, 2], [1, 2, 3], [1, 3], [2], [2, 3], [3]]

# %%
two_sum = TwoSum()
print(two_sum.solve([2, 7, 11, 15], 9))
# Out:
# (0, 1)

# %%
reverse_string = ReverseString()
reverse_string.solve("Hello dear world")
# Out:
# world dear Hello
