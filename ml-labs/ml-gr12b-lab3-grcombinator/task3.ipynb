# %%
# !sed '/book/ p' books.txt
# Out:
# Book one.
# The second book.
# The second book.
# The third.
# This is book four.
# This is book four.
# Five.
# This is the sixth.
# This is book seven.
# This is book seven.
# Eighth and last.

# %%
# !sed -n '/book/ p' books.txt
# Out:
# The second book.
# This is book four.
# This is book seven.

# %%
# !sed -n '2,5 p' books.txt
# Out:
# The second book.
# The third.
# This is book four.
# Five.

# %%
# !sed -n -f records.txt books.txt
# Out:
# The second book.
# The third.
# This is book four.
# Five.

# %%
# !sed -f appends.txt books.txt
# Out:
# Book one.
# The second book.
# The third.
# My favorite book.
# This is book four.
# Five.
# This is the sixth.
# This is book seven.
# Eighth and last.

# %%
# !sed -f insert.txt books.txt
# Out:
# Book one.
# The second book.
# The third.
# SKARBONKA.
# This is book four.
# Five.
# SKARBONKA.
# This is the sixth.
# SKARBONKA.
# This is book seven.
# Eighth and last.

# %%
# !sed -n 's/book/novel/ p' books.txt
# Out:
# The second novel.
# This is novel four.
# This is novel seven.
