# %% [markdown]
# ![Результат awk в терминале](screen1.png)

# %% [markdown]
# ![Результат awk в терминале](screen2.png)

# %% [markdown]
# ![Результат awk в терминале](screen3.png)

# %% [markdown]
# ![Результат awk в терминале](screen4.png)

# %% [markdown]
# ![Результат awk в терминале](screen5.png)

# %% [markdown]
# ![Результат awk в терминале](screen6.png)

# %%
# !awk '{print $0}' list_students.txt
# Out:
# Аринин Иван МП 1 4
# Бетинов Евгений ЭКТ 2 5
# Кошин Леонид МП 1 4
# Кошкин Владимир ЭКТ 1 5
# Липин Федор МП 2 3
# Пенов Николай МП 1 4
# Яшин Петр ЭКТ 2 4

# %%
# !awk '/5/ {print $0}' list_students.txt
# Out:
# Бетинов Евгений ЭКТ 2 5
# Кошкин Владимир ЭКТ 1 5

# %%
# !sed 's/Яшин/Кашин/' list_students.txt
# Out:
# Аринин Иван МП 1 4
# Бетинов Евгений ЭКТ 2 5
# Кошин Леонид МП 1 4
# Кошкин Владимир ЭКТ 1 5
# Липин Федор МП 2 3
# Пенов Николай МП 1 4
# Яшин Петр ЭКТ 2 4

# %%
# !sed 's/ЭКТ/КБ/' list_students.txt
# Out:
# Аринин Иван МП 1 4
# Бетинов Евгений ЭКТ 2 5
# Кошин Леонид МП 1 4
# Кошкин Владимир ЭКТ 1 5
# Липин Федор МП 2 3
# Пенов Николай МП 1 4
# Яшин Петр ЭКТ 2 4

# %%
# !sed 3,6d list_students.txt
# Out:
# Аринин Иван МП 1 4
# Бетинов Евгений ЭКТ 2 5
# Яшин Петр ЭКТ 2 4

# %%
# !sed '/ЭКТ/d' list_students.txt
# Out:
# Аринин Иван МП 1 4
# Бетинов Евгений ЭКТ 2 5
# Кошин Леонид МП 1 4
# Кошкин Владимир ЭКТ 1 5
# Липин Федор МП 2 3
# Пенов Николай МП 1 4
# Яшин Петр ЭКТ 2 4
